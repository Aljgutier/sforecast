# %% [markdown]
# # Classic Forecasting Models

# %% [markdown]
# * Import tests from the corresponding test_sklearn.py
# * Develoop and Debub Tests

# %% [markdown]
# # Imports

# %%
import beautifulplots as bp
import pandas as pd
import sforecast as sf
import numpy as np
from datetime import datetime

import beautifulplots as bp
import matplotlib.pyplot as plt
# Out:
# 2024-06-17 21:57:59.515055: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Arima

# %%
# data shampoo
def dateparser(x):
    return datetime.strptime('190'+x, '%Y-%m')
df_shampoo = pd.read_csv("../data/shampoo.csv", parse_dates = ["Month"], date_parser=dateparser)

display(df_shampoo.head())
bp.lineplot(df_shampoo, x = "Month", y="Sales", figsize=(18,6), y_axis_format=".0f")
# Out:
#        Month  Sales
# 0 1901-01-01  266.0
# 1 1901-02-01  145.9
# 2 1901-03-01  183.1
# 3 1901-04-01  119.3
# 4 1901-05-01  180.3

# %%
from test_classical import test_arima

df_pred_arima=test_arima()

display(df_pred_arima.tail())
# Out:
#     Sales_train  Sales_test  Sales_pred  Sales_pred_error  Sales_pred_lower  \
# 31          NaN       407.6  467.811682         60.211682        321.109698
# 32          NaN       682.0  519.261277       -162.738723        372.559293
# 33          NaN       475.3  464.182016        -11.117984        317.480032
# 34          NaN       581.3  615.984739         34.684739        469.282755
# 35          NaN       646.9  524.253124       -122.646876        377.551140
#
#     Sales_pred_upper
# 31        517.812587
# 32        569.262182
# 33        514.182921
# 34        665.985644
# 35        574.254029

# %% [markdown]
# # SARIMAX

# %%
#data
#https://www.kaggle.com/datasets/rakannimer/air-passengers?resource=download

df_airp = pd.read_csv("../data/AirPassengers.csv", parse_dates = ["Month"]).set_index("Month")
display(df_airp.head())

# rows with NA
print("rows with NA")
display(df_airp[df_airp.isna().any(axis=1)])

bp.lineplot(df_airp.reset_index(), x="Month", y=["Passengers"], figsize=(18,6))
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# rows with NA
# Empty DataFrame
# Columns: [Passengers]
# Index: []

# %%
from test_classical import test_sarimax

# %%
df_pred_sarimax=test_sarimax()

display(df_pred_sarimax.tail())
# Out:
#             Passengers_pred
# 1961-01-01       444.327801

# %% [markdown]
# # SARIMAX w Exog and Endog

# %% [markdown]
# test sarimax with exog and endog variables

# %%
from test_classical import test_sarimax_exog_endog

df_pred_sarimax = test_sarimax_exog_endog()

display(df_pred_sarimax)
# Out:
#             Passengers_train  Passengers_test  Passengers_pred  \
# Month
# 1949-01-01             112.0              NaN              NaN
# 1949-02-01             118.0              NaN              NaN
# 1949-03-01             132.0              NaN              NaN
# 1949-04-01             129.0              NaN              NaN
# 1949-05-01             121.0              NaN              NaN
# ...                      ...              ...              ...
# 1960-08-01               NaN            606.0       629.985383
# 1960-09-01               NaN            508.0       517.862159
# 1960-10-01               NaN            461.0       453.553138
# 1960-11-01               NaN            390.0       414.046039
# 1960-12-01               NaN            432.0       444.912872
#
#             Passengers_pred_error  Passengers_pred_lower  \
# Month
# 1949-01-01                    NaN                    NaN
# 1949-02-01                    NaN                    NaN
# ...

# %% [markdown]
# # Auto Arima

# %%
from test_classical import test_autoarima

df_pred_autoarima = test_autoarima()

display(df_pred_autoarima)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=inf, Time=0.82 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=999.041, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=988.030, Time=0.05 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=988.606, Time=0.09 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=987.497, Time=0.02 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=988.367, Time=0.08 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.23 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=989.465, Time=0.04 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=989.427, Time=0.03 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=987.923, Time=0.02 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=985.987, Time=0.12 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=986.643, Time=0.38 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=986.912, Time=0.34 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=inf, Time=0.43 sec
# ...
